# %% [markdown]
# #  "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# __Roland Tokos__
#
# Data Scientist

# %% [markdown]
# _I am intrested in data science because I would like to make relevant predictions in healthcare. I would love to tell a story about how raw data was transformed for something beautiful._

# %% [markdown]
# ### The below code should print "Hello World."

# %%
print("Hello World.")
# Out:
# Hello World.

# %% [markdown]
# This course is cool.
#
# ---
#
# I love data.
#
# ---
#
# Analysis is important.
#
#
# 1. Fruits
# * Lemon
# * Orange
# * Pineapple
#
#
# [Click on IBM to know more](www.ibm.com)
#
#
# Inline-style:
# ![alt text](https://github.com/rolandtokos/data_rt/blob/b3d8271ffa3fe4d180860d78f00c38f7e1e655b5/cat.jpg "Logo Title Text 1")
#
#
# ```python
# syntax = "Highlight print Syntax"
# print syntax
# ```
#
# > This line is a quote.
#
#
# | Viruses  | Bacteria  | Mushroom  |
# |---|---|---|
# | SARS  | S. Aureus  |Candida   |
# | MERS | Diphteria  |  Trichophyton |
# | Covid-19  | Pseudomonas   | Microsporon  |
